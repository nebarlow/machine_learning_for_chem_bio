# %% [markdown]
# ### HackEDU Machine Learning and Data Science for Chemical Biology - Lecture 3 - Nov 11th, 2019
#
# Taught by Nathan Barlow: nathan.barlow@imperial.ac.uk
# TAs: Rob Strutt and Hisham Abdel Aty: r.strutt17@imperial.ac.uk , hisham.abdel-aty15@imperial.ac.uk
#
# # Special Guest Speaker - Eyal Kazin - From LabGenius

# %% [markdown]
# # Last half of class - How to Handle Proteomtic Data (Ed Tate Lab)
#
# Volcano plots are used to look for statistically interesting changes in an experiment. It requires:
#
# 1. A control set
# 2. Replicates (at least 3 repeats)
# 3. A large data set

# %%
from IPython.display import Image
Image('volcano.jpg')

# %% [markdown]
# ### Practical Example: We have proteomic data where we have 7 experimental conditions to compare to a control. Our goal is to

# %% [markdown]
# ## 1-Hour Lab Practical
#
# ### Part 1
#
# This is a subset of dataset from Ogishi & Yotsuyanagi focusing on the MHC-I peptides from Chowell et al. 2015.
#
# The data from LabGenius is similar in essence to this: sequence and a score (categorical or numerical) for protein function or an experimental selection.
#
# Open the file "mhc1-peptides.csv" and try to build a classifier model.
#
# Hint: Somethine like one-hot encoding might be useful.
#
#
# ### Part 2
#
# We have proteomic data "testPerseus.txt" that we want display in a volcano plot. The data is broken up conditions 0 to 7 where condition 1 is the control, along with replicates 1,2,3. A volcano plot has log2(fold change) on the x axis and -log10(p-value) on the y axis.
#
# It is recommended to get p values from the package "from scipy.stats import ttest_ind"
#
# Regarding the data analysis, we do the following:
#
# 1. read the data into a pandas dataframe
#
#  hint: the data is separated by a tap "\t"
#
# 2. build the data into a tensor [gene, condition, replicate]
#
#  hint: use f string -> "f'{cond} YnMyr_HeLa_{rep}'"
#
# 3. get the fold change relative to condition 1
# 4. get the p value relative to condition 1
#
#  hint: "from scipy.stats import ttest_ind"
